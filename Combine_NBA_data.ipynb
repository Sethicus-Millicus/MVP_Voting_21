# %%
import pandas as pd

# %%
df_adv = pd.read_csv('NBA_final_stats/overall_advanced.csv', index_col=0)
df_per = pd.read_csv('NBA_final_stats/overall_per_game.csv', index_col=0)
df_mvp = pd.read_csv('NBA_final_stats/total_mvp_voting.csv', index_col=0)

# %%
df_adv.head(10)
# Out:
#     Season               Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0  1979-80  Kareem Abdul-Jabbar   C   32  LAL  82  3143  25.3  0.639  0.001
# 1  1979-80        Tom Abernethy  PF   25  GSW  67  1222  11.0  0.511  0.003
# 2  1979-80          Alvan Adams   C   25  PHO  75  2168  19.2  0.571  0.002
# 3  1979-80       Tiny Archibald  PG   31  BOS  80  2864  15.3  0.574  0.023
# 4  1979-80        Dennis Awtrey   C   31  CHI  26   560   7.4  0.524  0.000
# 5  1979-80           Gus Bailey  SG   28  WSB  20   180   9.3  0.467  0.029
# 6  1979-80         James Bailey  PF   22  SEA  67   726  12.3  0.495  0.000
# 7  1979-80         Greg Ballard  SF   25  WSB  82  2438  18.1  0.532  0.043
# 8  1979-80          Mike Bantom  SF   28  IND  77  2330  13.7  0.533  0.004
# 9  1979-80        Marvin Barnes  PF   27  SDC  20   287   8.2  0.432  0.000
#
#    ...  BLK%  USG%  OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP
# 0  ...   4.6  24.1  9.5  5.3  14.8  0.227   4.8   2.4  7.2   7.3
# ...

# %%
df_per.head(10)
# Out:
#     Season               Player Pos  Age   Tm   G    MP    FG   FGA    FG%  \
# 0  1979-80  Kareem Abdul-Jabbar   C   32  LAL  82  38.3  10.2  16.9  0.604
# 1  1979-80        Tom Abernethy  PF   25  GSW  67  18.2   2.3   4.7  0.481
# 2  1979-80          Alvan Adams   C   25  PHO  75  28.9   6.2  11.7  0.531
# 3  1979-80       Tiny Archibald  PG   31  BOS  80  35.8   4.8   9.9  0.482
# 4  1979-80        Dennis Awtrey   C   31  CHI  26  21.5   1.0   2.3  0.450
# 5  1979-80           Gus Bailey  SG   28  WSB  20   9.0   0.8   1.8  0.457
# 6  1979-80         James Bailey  PF   22  SEA  67  10.8   1.8   4.0  0.450
# 7  1979-80         Greg Ballard  SF   25  WSB  82  29.7   6.6  13.4  0.495
# 8  1979-80          Mike Bantom  SF   28  IND  77  30.3   5.0   9.9  0.505
# 9  1979-80        Marvin Barnes  PF   27  SDC  20  14.4   1.2   3.0  0.400
#
#    ...   eFG%   FT  FTA    FT%   TRB  AST  STL  BLK  TOV   PTS
# 0  ...  0.604  4.4  5.8  0.765  10.8  4.5  1.0  3.4  3.6  24.8
# ...

# %%
df_mvp.head(10)
# Out:
#     Season               Player  Age   Tm  First  Pts Won  Pts Max  Share   G  \
# 0  1979-80  Kareem Abdul-Jabbar   32  LAL  147.0    147.0      221  0.665  82
# 1  1979-80        Julius Erving   29  PHI   31.5     31.5      221  0.143  78
# 2  1979-80        George Gervin   27  SAS   19.0     19.0      221  0.086  78
# 3  1979-80           Larry Bird   23  BOS   15.0     15.0      221  0.068  82
# 4  1979-80       Tiny Archibald   31  BOS    2.0      2.0      221  0.009  80
# 5  1979-80       Dennis Johnson   25  SEA    2.0      2.0      221  0.009  81
# 6  1979-80       Dan Roundfield   26  ATL    2.0      2.0      221  0.009  81
# 7  1979-80         Gus Williams   26  SEA    1.5      1.5      221  0.007  82
# 8  1979-80         Moses Malone   24  HOU    1.0      1.0      221  0.005  82
# 9  1980-81        Julius Erving   30  PHI   28.0    454.0      690  0.658  82
#
#      MP   PTS   TRB  AST  STL  BLK    FG%    3P%    FT%    WS  WS/48
# ...

# %%
combine = pd.merge(df_per, df_adv, on=['Season','Player','Pos', 'Age', 'Tm', 'G',] )

# %%
combine_all = pd.merge(combine, df_mvp_merge, on=['Season','Player',] )

# %%
combine_all.to_csv('mvp_voting.csv')

# %%
combine_all
# Out:
#       Season          Player Pos   Age   Tm     G    GS  MP_x    FG   FGA  \
# 0    1979-80  Dan Roundfield  PF  26.0  ATL  81.0   NaN  32.0   6.2  12.4
# 1    1979-80    Gus Williams  PG  26.0  SEA  82.0   NaN  36.2   9.0  18.7
# 2    1980-81   Otis Birdsong  SG  25.0  KCK  71.0   NaN  36.5  10.0  18.4
# 3    1980-81   Quinn Buckner  PG  26.0  MIL  82.0   NaN  29.1   5.7  11.7
# 4    1980-81  Michael Cooper  SG  24.0  LAL  81.0   NaN  32.4   4.0   8.1
# ..       ...             ...  ..   ...  ...   ...   ...   ...   ...   ...
# 339  2019-20   Kawhi Leonard  SF  28.0  LAC  57.0  57.0  32.4   9.3  19.9
# 340  2019-20  Damian Lillard  PG  29.0  POR  66.0  66.0  37.5   9.5  20.4
# 341  2019-20      Chris Paul  PG  34.0  OKC  70.0  70.0  31.5   6.2  12.7
# 342  2019-20   Pascal Siakam  PF  25.0  TOR  60.0  60.0  35.2   8.3  18.4
# 343  2019-20    Jayson Tatum  PF  21.0  BOS  66.0  66.0  34.3   8.4  18.6
#
#      ...   .1  OBPM  DBPM  BPM  VORP  First    MP  Pts Max  Pts Won  Share
# ...

# %%
combine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39827 entries, 0 to 39826
# Data columns (total 53 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Season  39827 non-null  object
#  1   Player  21655 non-null  object
#  2   Pos     21655 non-null  object
#  3   Age     21655 non-null  float64
#  4   Tm      21655 non-null  object
#  5   G       21655 non-null  float64
#  6   GS      20982 non-null  float64
#  7   MP_x    21655 non-null  float64
#  8   FG      21655 non-null  float64
#  9   FGA     21655 non-null  float64
#  10  FG%     21553 non-null  float64
#  11  3P      21655 non-null  float64
#  12  3PA     21655 non-null  float64
#  13  3P%     17962 non-null  float64
#  14  2P      21655 non-null  float64
#  15  2PA     21655 non-null  float64
#  16  2P%     21493 non-null  float64
#  17  eFG%    21553 non-null  float64
#  18  FT      21655 non-null  float64
#  19  FTA     21655 non-null  float64
# ...

# %%
cols_to_use = df_mvp.columns.difference(combine.columns)

# %%
cols_to_use.to_list()
# Out:
# ['First', 'MP', 'Pts Max', 'Pts Won', 'Share']

# %%
df_mvp_merge = df_mvp[['Season', 'Player', 'First', 'MP', 'Pts Max', 'Pts Won', 'Share']]

# %%
import pandas as pd

# %%
df_adv = pd.read_csv('NBA_by_year_stats/2021_advanced.csv', index_col=0)
df_per = pd.read_csv('NBA_by_year_stats/2021_per_game.csv', index_col=0)
#df_mvp = pd.read_csv('NBA_final_stats/total_mvp_voting.csv', index_col=0)

# %%
df_adv.head(10)
# Out:
#         yr                    Player Pos   Age   Tm     G      MP   PER  \
# 0  2020-21          Precious Achiuwa  PF  21.0  MIA  61.0   737.0  14.2
# 1  2020-21              Jaylen Adams  PG  24.0  MIL   7.0    18.0  -6.5
# 2  2020-21              Steven Adams   C  27.0  NOP  58.0  1605.0  15.1
# 3  2020-21               Bam Adebayo   C  23.0  MIA  64.0  2143.0  22.7
# 4  2020-21         LaMarcus Aldridge   C  35.0  TOT  26.0   674.0  15.7
# 5  2020-21         LaMarcus Aldridge   C  35.0  SAS  21.0   544.0  15.1
# 6  2020-21         LaMarcus Aldridge   C  35.0  BRK   5.0   130.0  18.2
# 7  2020-21         Ty-Shon Alexander  SG  22.0  PHO  15.0    47.0   4.2
# 8  2020-21  Nickeil Alexander-Walker  SG  22.0  NOP  46.0  1007.0  12.5
# 9  2020-21             Grayson Allen  SG  25.0  MEM  50.0  1259.0  12.8
#
#      TS%   3PAr  ...      OWS  DWS   WS  WS/48   .1  OBPM  DBPM   BPM  VORP
# 0  0.550  0.004  ... NaN  0.3  1.0  1.3  0.085  NaN  -3.5  -0.9  -4.5  -0.5
# ...

# %%
df_per.head(10)
# Out:
#         yr                    Player Pos   Age   Tm     G    GS    MP   FG  \
# 0  2020-21          Precious Achiuwa  PF  21.0  MIA  61.0   4.0  12.1  2.0
# 1  2020-21              Jaylen Adams  PG  24.0  MIL   7.0   0.0   2.6  0.1
# 2  2020-21              Steven Adams   C  27.0  NOP  58.0  58.0  27.7  3.3
# 3  2020-21               Bam Adebayo   C  23.0  MIA  64.0  64.0  33.5  7.1
# 4  2020-21         LaMarcus Aldridge   C  35.0  TOT  26.0  23.0  25.9  5.4
# 5  2020-21         LaMarcus Aldridge   C  35.0  SAS  21.0  18.0  25.9  5.5
# 6  2020-21         LaMarcus Aldridge   C  35.0  BRK   5.0   5.0  26.0  5.0
# 7  2020-21         Ty-Shon Alexander  SG  22.0  PHO  15.0   0.0   3.1  0.2
# 8  2020-21  Nickeil Alexander-Walker  SG  22.0  NOP  46.0  13.0  21.9  4.2
# 9  2020-21             Grayson Allen  SG  25.0  MEM  50.0  38.0  25.2  3.5
#
#     FGA  ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0   3.7  ...  0.509  1.2  2.2  3.4  0.5  0.3  0.5  0.7  1.5   5.0
# ...

# %%
combine = pd.merge(df_per, df_adv, on=['yr','Player','Pos', 'Age', 'Tm', 'G',] )

# %%
combine.rename(columns={'MP_x':'MP'}, inplace=True)

# %%
combine
# Out:
#            yr             Player Pos   Age   Tm     G    GS    MP   FG   FGA  \
# 0     2020-21   Precious Achiuwa  PF  21.0  MIA  61.0   4.0  12.1  2.0   3.7
# 1     2020-21       Jaylen Adams  PG  24.0  MIL   7.0   0.0   2.6  0.1   1.1
# 2     2020-21       Steven Adams   C  27.0  NOP  58.0  58.0  27.7  3.3   5.3
# 3     2020-21        Bam Adebayo   C  23.0  MIA  64.0  64.0  33.5  7.1  12.5
# 4     2020-21  LaMarcus Aldridge   C  35.0  TOT  26.0  23.0  25.9  5.4  11.4
# ...       ...                ...  ..   ...  ...   ...   ...   ...  ...   ...
# 1376  2020-21       Delon Wright  PG  28.0  SAC  27.0   8.0  25.8  3.9   8.3
# 1377  2020-21     Thaddeus Young  PF  32.0  CHI  68.0  23.0  24.3  5.4   9.7
# 1378  2020-21         Trae Young  PG  22.0  ATL  63.0  63.0  33.7  7.7  17.7
# 1379  2020-21        Cody Zeller   C  28.0  CHO  48.0  21.0  20.9  3.8   6.8
# 1380  2020-21        Ivica Zubac   C  23.0  LAC  72.0  33.0  22.3  3.6   5.5
#
# ...

# %%
df_per.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 731 entries, 0 to 730
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   yr      731 non-null    object
#  1   Player  705 non-null    object
#  2   Pos     705 non-null    object
#  3   Age     705 non-null    float64
#  4   Tm      705 non-null    object
#  5   G       705 non-null    float64
#  6   GS      705 non-null    float64
#  7   MP      705 non-null    float64
#  8   FG      705 non-null    float64
#  9   FGA     705 non-null    float64
#  10  FG%     703 non-null    float64
#  11  3P      705 non-null    float64
#  12  3PA     705 non-null    float64
#  13  3P%     670 non-null    float64
#  14  2P      705 non-null    float64
#  15  2PA     705 non-null    float64
#  16  2P%     699 non-null    float64
#  17  eFG%    703 non-null    float64
#  18  FT      705 non-null    float64
#  19  FTA     705 non-null    float64
#  20  FT%     676 non-null    float64
# ...

# %%
df_adv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 731 entries, 0 to 730
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   yr      731 non-null    object
#  1   Player  705 non-null    object
#  2   Pos     705 non-null    object
#  3   Age     705 non-null    float64
#  4   Tm      705 non-null    object
#  5   G       705 non-null    float64
#  6   MP      705 non-null    float64
#  7   PER     705 non-null    float64
#  8   TS%     703 non-null    float64
#  9   3PAr    703 non-null    float64
#  10  FTr     703 non-null    float64
#  11  ORB%    705 non-null    float64
#  12  DRB%    705 non-null    float64
#  13  TRB%    705 non-null    float64
#  14  AST%    705 non-null    float64
#  15  STL%    705 non-null    float64
#  16  BLK%    705 non-null    float64
#  17  TOV%    704 non-null    float64
#  18  USG%    705 non-null    float64
#  19          0 non-null      float64
#  20  OWS     705 non-null    float64
# ...

# %%
combine.to_csv('NBA_final_stats/2021_complete_stats.csv')
